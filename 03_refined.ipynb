# %%
import math
import pandas as pd 
import os
import numpy as np

# %%
caminho_dos_arquivos = r'dados/trusted/voos/'

# %%
nomes_dos_arquivos = [
    "dados_voo_202406.csv",
    "dados_voo_202407.csv",
    "dados_voo_202408.csv",
    "dados_voo_202409.csv",
    "dados_voo_202410.csv",
    "dados_voo_202411.csv",
    "dados_voo_202412.csv"
]

# %%
lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]

df_final = pd.concat(lista_de_dfs, ignore_index=True)

df_final.head(5)
print(f"\nNúmero total de linhas no DataFrame final: {len(df_final)}")
# Out:
# C:\Users\ivanm\AppData\Local\Temp\ipykernel_19184\47014420.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]
# C:\Users\ivanm\AppData\Local\Temp\ipykernel_19184\47014420.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]
# Número total de linhas no DataFrame final: 451380
# C:\Users\ivanm\AppData\Local\Temp\ipykernel_19184\47014420.py:1: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]

# %%
df_final
# Out:
#        SIGLA ICAO EMPRESA AEREA  \
# 0                           CLX
# 1                           GLO
# 2                           GLO
# 3                           GLO
# 4                           LCO
# ...                         ...
# 451375                      UKL
# 451376                      UKL
# 451377                      UKL
# 451378                      UKL
# 451379                      UKL
#
#                                             EMPRESA AEREA NUMERO VOO  \
# 0                     CARGOLUX AIRLINES INTERNATIONAL S/A       6225
# 1       GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       1766
# 2       GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       1798
# 3       GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       9621
# 4                                          LAN CARGO S.A.       1751
# ...                                                   ...        ...
# 451375                      UKRAINE AIR ALLIANCE AIRLINES       5080
# 451376                      UKRAINE AIR ALLIANCE AIRLINES       5004
# 451377                      UKRAINE AIR ALLIANCE AIRLINES       5005
# 451378                      UKRAINE AIR ALLIANCE AIRLINES       5016
# 451379                      UKRAINE AIR ALLIANCE AIRLINES       5017
#
#        CODIGO DI CODIGO TIPO LINHA MODELO EQUIPAMENTO  NUMERO DE ASSENTOS  \
# 0              0                 G               B744                 0.0
# 1              0                 N               B38M               186.0
# 2              0                 N               B38M               186.0
# 3              0                 C               B738                 0.0
# 4              0                 G               B763                 0.0
# ...          ...               ...                ...                 ...
# 451375         9                 I               AN12                 0.0
# 451376         2                 I               AN12                 0.0
# 451377         6                 I               AN12                 0.0
# 451378         2                 I               AN12                 0.0
# 451379         6                 I               AN12                 0.0
#
#        SIGLA AEROPORTO ORIGEM  PARTIDA PREVISTA      PARTIDA REAL  ...  \
# 0                        SBKP  01/06/2024 06:00  01/06/2024 05:58  ...
# 1                        SBBE  01/06/2024 00:35  01/06/2024 00:24  ...
# 2                        SBRB  01/06/2024 00:50  01/06/2024 03:35  ...
# 3                        SBEG  01/06/2024 02:00  01/06/2024 02:35  ...
# 4                        SBGL  01/06/2024 08:05  01/06/2024 08:11  ...
# ...                       ...               ...               ...  ...
# 451375                   SBEG  13/12/2024 06:00  13/12/2024 09:17  ...
# 451376                   SBSG  15/12/2024 07:00               NAN  ...
# 451377                   SBGL  16/12/2024 09:00  16/12/2024 09:28  ...
# 451378                   SBEG  25/12/2024 08:00               NAN  ...
# 451379                   SBSJ  26/12/2024 03:00  26/12/2024 10:44  ...
#
#        LATITUDE ORIG LONGITUDE ORIG CODIGO OACI_y CIAD DEST  \
# 0         -23.006944     -47.134444          SBCT    PR0001
# 1          -1.384722     -48.478889          SBSN    PA0002
# 2          -9.868333     -67.898056          SBCZ    AC0002
# 3          -3.041111     -60.050556          SBGR    SP0002
# 4         -22.810000     -43.250556          SBKP    SP0003
# ...              ...            ...           ...       ...
# 451375     -3.041111     -60.050556          SBSJ    SP0008
# 451376     -5.768889     -35.366389          SBGL    RJ0001
# 451377    -22.810000     -43.250556          SBEG    AM0001
# 451378     -3.041111     -60.050556          SBSJ    SP0008
# 451379    -23.228889     -45.871111          SBEG    AM0001
#
#                                            NOME DEST       MUNICIPIO DEST  \
# 0                                        AFONSO PENA             CURITIBA
# 1                             MAESTRO WILSON FONSECA             SANTAREM
# 2                                    CRUZEIRO DO SUL      CRUZEIRO DO SUL
# 3        GUARULHOS - GOVERNADOR ANDRE FRANCO MONTORO            GUARULHOS
# 4                                          VIRACOPOS             CAMPINAS
# ...                                              ...                  ...
# 451375               PROFESSOR URBANO ERNESTO STUMPF  SAO JOSE DOS CAMPOS
# 451376  RIO DE JANEIRO/GALEAO – ANTONIO CARLOS JOBIM       RIO DE JANEIRO
# 451377                                 EDUARDO GOMES               MANAUS
# 451378               PROFESSOR URBANO ERNESTO STUMPF  SAO JOSE DOS CAMPOS
# 451379                                 EDUARDO GOMES               MANAUS
#
#        UF DEST LATITUDE DEST LONGITUDE DEST DISTANCIA KM
# 0           PR    -25.531667     -49.176111   348.759491
# 1           PA     -2.424722     -54.785833   710.378651
# 2           AC     -7.599444     -72.769444   591.819954
# 3           SP    -23.435556     -46.473056  2697.275751
# 4           SP    -23.006944     -47.134444   398.396819
# ...        ...           ...            ...          ...
# 451375      SP    -23.228889     -45.871111  2714.305622
# 451376      RJ    -22.810000     -43.250556  2075.064170
# 451377      AM     -3.041111     -60.050556  2847.404725
# 451378      SP    -23.228889     -45.871111  2714.305622
# 451379      AM     -3.041111     -60.050556  2714.305622
#
# [451380 rows x 33 columns]

# %%
df_final.isnull().sum().sort_values(ascending=False)
# Out:
# DISTANCIA KM                3155
# LATITUDE DEST               1582
# MUNICIPIO DEST              1582
# NOME DEST                   1582
# CODIGO OACI_y               1582
# LONGITUDE DEST              1582
# UF DEST                     1582
# CIAD DEST                   1582
# LATITUDE ORIG               1573
# LONGITUDE ORIG              1573
# CODIGO OACI_x               1573
# NOME ORIG                   1573
# CIAD ORIG                   1573
# MUNICIPIO ORIG              1573
# UF ORIG                     1573
# SIGLA ICAO EMPRESA AEREA       0
# EMPRESA AEREA                  0
# SITUACAO PARTIDA               0
# REFERENCIA                     0
# JUSTIFICATIVA                  0
# SITUACAO VOO                   0
# CHEGADA REAL                   0
# CHEGADA PREVISTA               0
# SIGLA AEROPORTO DESTINO        0
# PARTIDA REAL                   0
# PARTIDA PREVISTA               0
# SIGLA AEROPORTO ORIGEM         0
# NUMERO DE ASSENTOS             0
# MODELO EQUIPAMENTO             0
# CODIGO TIPO LINHA              0
# CODIGO DI                      0
# NUMERO VOO                     0
# SITUACAO CHEGADA               0
# dtype: int64

# %%
print(len(df_final))
# Out:
# 451380

# %%
novos_nomes = {
    'SIGLA ICAO AEROPORTO DESTINO' : 'SIGLA AEROPORTO DESTINO',
    'MUNICIPIO ATENDIDO ORIG' : 'MUNICIPIO ORIG',
    'MUNICIPIO ATENDIDO DEST' : 'MUNICIPIO DEST',
    'SIGLA ICAO AEROPORTO ORIGEM' : 'SIGLA AEROPORTO ORIGEM',
}

df_final.rename(columns=novos_nomes, inplace=True)

# %%
df_final = df_final[
    (df_final['UF ORIG'] == 'SP') & 
    (df_final['MUNICIPIO ORIG'] == 'SAO PAULO') & 
    (df_final['MUNICIPIO DEST'] == 'RIO DE JANEIRO') & 
    (df_final['UF DEST'] == 'RJ')
].copy()

print(f"\nNúmero total de voos de São Paulo para Rio de Janeiro: {len(df_final)}")
# Out:
# Número total de voos de São Paulo para Rio de Janeiro: 12693

# %%
df_final['PARTIDA REAL'] = pd.to_datetime(df_final['PARTIDA REAL'], format='%d/%m/%Y %H:%M', errors='coerce')

df_final['HORA PARTIDA REAL'] = df_final['PARTIDA REAL'].dt.time

# %%
def mapear_cluster_hora(hora_integer):
    if 0 <= hora_integer < 2:
        return 1
    elif 2 <= hora_integer < 4:
        return 2
    elif 4 <= hora_integer < 6:
        return 3
    elif 6 <= hora_integer < 8:
        return 4
    elif 8 <= hora_integer < 10:
        return 5
    elif 10 <= hora_integer < 12:
        return 6
    elif 12 <= hora_integer < 14:
        return 7
    elif 14 <= hora_integer < 16:
        return 8
    elif 16 <= hora_integer < 18:
        return 9
    elif 18 <= hora_integer < 20:
        return 10
    elif 20 <= hora_integer < 22:
        return 11
    elif 22 <= hora_integer <= 23:
        return 12
    else:
        return np.nan


df_final['CLUSTER_HORA'] = df_final['PARTIDA REAL'].dt.hour.apply(mapear_cluster_hora)

# %%
df_final['AQO'] = df_final['NUMERO DE ASSENTOS'] * df_final['DISTANCIA KM']

# %%
df_final
# Out:
#        SIGLA ICAO EMPRESA AEREA                                EMPRESA AEREA  \
# 11                          ACN  AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
# 13                          ACN  AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
# 16                          ACN  AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
# 24                          ACN  AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
# 25                          ACN  AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
# ...                         ...                                          ...
# 451061                      TAM                       TAM LINHAS AEREAS S.A.
# 451063                      TAM                       TAM LINHAS AEREAS S.A.
# 451066                      TAM                       TAM LINHAS AEREAS S.A.
# 451067                      TAM                       TAM LINHAS AEREAS S.A.
# 451068                      TAM                       TAM LINHAS AEREAS S.A.
#
#        NUMERO VOO CODIGO DI CODIGO TIPO LINHA MODELO EQUIPAMENTO  \
# 11           5121         0                 N               C208
# 13           5232         0                 N               C208
# 16           5114         0                 N               C208
# 24           5220         0                 N               C208
# 25           5226         0                 N               C208
# ...           ...       ...               ...                ...
# 451061       3930         0                 N               A319
# 451063       3932         0                 N               A319
# 451066       3938         0                 N               A319
# 451067       3940         0                 N               A319
# 451068       3944         0                 N               A319
#
#         NUMERO DE ASSENTOS SIGLA AEROPORTO ORIGEM  PARTIDA PREVISTA  \
# 11                     9.0                   SBSP  01/06/2024 06:25
# 13                     9.0                   SBSP  01/06/2024 10:45
# 16                     9.0                   SBSP  02/06/2024 15:40
# 24                     9.0                   SBSP  02/06/2024 13:40
# 25                     9.0                   SBSP  02/06/2024 20:10
# ...                    ...                    ...               ...
# 451061               144.0                   SBSP  31/12/2024 12:00
# 451063               144.0                   SBSP  31/12/2024 19:40
# 451066               144.0                   SBSP  31/12/2024 20:35
# 451067               144.0                   SBSP  31/12/2024 20:55
# 451068               144.0                   SBSP  31/12/2024 20:00
#
#               PARTIDA REAL  ... CIAD DEST                      NOME DEST  \
# 11     2024-06-01 06:20:00  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 13     2024-06-01 10:40:00  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 16     2024-06-02 15:38:00  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 24     2024-06-02 13:33:00  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 25     2024-06-02 20:17:00  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# ...                    ...  ...       ...                            ...
# 451061 2024-12-31 12:04:00  ...    RJ0002                  SANTOS DUMONT
# 451063 2024-12-31 19:35:00  ...    RJ0002                  SANTOS DUMONT
# 451066 2024-12-31 20:22:00  ...    RJ0002                  SANTOS DUMONT
# 451067 2024-12-31 20:47:00  ...    RJ0002                  SANTOS DUMONT
# 451068 2024-12-31 19:49:00  ...    RJ0002                  SANTOS DUMONT
#
#         MUNICIPIO DEST UF DEST LATITUDE DEST LONGITUDE DEST DISTANCIA KM  \
# 11      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 13      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 16      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 24      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 25      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# ...                ...     ...           ...            ...          ...
# 451061  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451063  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451066  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451067  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451068  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
#
#        HORA PARTIDA REAL CLUSTER_HORA           AQO
# 11              06:20:00          4.0   3087.278232
# 13              10:40:00          6.0   3087.278232
# 16              15:38:00          8.0   3087.278232
# 24              13:33:00          7.0   3087.278232
# 25              20:17:00         11.0   3087.278232
# ...                  ...          ...           ...
# 451061          12:04:00          7.0  52656.118920
# 451063          19:35:00         10.0  52656.118920
# 451066          20:22:00         11.0  52656.118920
# 451067          20:47:00         11.0  52656.118920
# 451068          19:49:00         10.0  52656.118920
#
# [12693 rows x 36 columns]

# %%
caminho_dos_arquivos = r'dados/trusted/reclamacoes/'

nomes_dos_arquivos = [
    "reclamacoes202406.csv",
    "reclamacoes202407.csv",
    "reclamacoes202408.csv",
    "reclamacoes202409.csv",
    "reclamacoes202410.csv",
    "reclamacoes202411.csv",
    "reclamacoes202412.csv"
]

# %%
lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]

df_rec = pd.concat(lista_de_dfs, ignore_index=True)

df_rec.head(5)
print(f"\nNúmero total de linhas no DataFrame de reclamações: {len(df_rec)}")
# Out:
# Número total de linhas no DataFrame de reclamações: 53732

# %%
df_rec
# Out:
#                                             GESTOR REGIAO  UF       CIDADE  \
# 0                SECRETARIA NACIONAL DO CONSUMIDOR     CO  DF     BRASILIA
# 1                SECRETARIA NACIONAL DO CONSUMIDOR     CO  DF     BRASILIA
# 2                SECRETARIA NACIONAL DO CONSUMIDOR     CO  DF     BRASILIA
# 3                SECRETARIA NACIONAL DO CONSUMIDOR     CO  DF     BRASILIA
# 4                SECRETARIA NACIONAL DO CONSUMIDOR     CO  DF     BRASILIA
# ...                                            ...    ...  ..          ...
# 53727  FUNDACAO DE PROTECAO E DEFESA DO CONSUMIDOR     SE  SP      VINHEDO
# 53728  FUNDACAO DE PROTECAO E DEFESA DO CONSUMIDOR     SE  SP   VOTORANTIM
# 53729  FUNDACAO DE PROTECAO E DEFESA DO CONSUMIDOR     SE  SP   VOTORANTIM
# 53730  FUNDACAO DE PROTECAO E DEFESA DO CONSUMIDOR     SE  SP   VOTORANTIM
# 53731  FUNDACAO DE PROTECAO E DEFESA DO CONSUMIDOR     SE  SP  VOTUPORANGA
#
#        ANO ABERTURA  MES ABERTURA DATA ABERTURA DATA E HORA RESPOSTA  \
# 0              2024             6    01/06/2024  02/06/2024 10:50:33
# 1              2024             6    01/06/2024  03/06/2024 08:50:42
# 2              2024             6    01/06/2024  03/06/2024 10:11:20
# 3              2024             6    01/06/2024  04/06/2024 11:11:38
# 4              2024             6    01/06/2024  04/06/2024 17:59:21
# ...             ...           ...           ...                  ...
# 53727          2024            12    27/12/2024  03/01/2025 19:36:39
# 53728          2024            12    20/12/2024  27/12/2024 10:38:32
# 53729          2024            12    22/12/2024  30/12/2024 10:19:32
# 53730          2024            12    23/12/2024  31/12/2024 08:23:39
# 53731          2024            12    23/12/2024  24/12/2024 12:25:38
#
#       DATA E HORA ANALISE DATA E HORA RECUSA  ...  \
# 0                     NAN                NAN  ...
# 1                     NAN                NAN  ...
# 2                     NAN                NAN  ...
# 3                     NAN                NAN  ...
# 4                     NAN                NAN  ...
# ...                   ...                ...  ...
# 53727                 NAN                NAN  ...
# 53728                 NAN                NAN  ...
# 53729                 NAN                NAN  ...
# 53730                 NAN                NAN  ...
# 53731                 NAN                NAN  ...
#
#                                                 PROBLEMA FORMA CONTRATO  \
# 0      COBRANCA INDEVIDA / ABUSIVA PARA ALTERAR OU CA...       INTERNET
# 1      COBRANCA DE TARIFAS, TAXAS, VALORES NAO PREVIS...       INTERNET
# 2      DIFICULDADE / ATRASO NA DEVOLUCAO DE VALORES P...       INTERNET
# 3      EXTRAVIO/ AVARIA DE BAGAGEM, CARGA, CORRESPOND...       INTERNET
# 4      DIFICULDADE / ATRASO NA DEVOLUCAO DE VALORES P...       INTERNET
# ...                                                  ...            ...
# 53727  EXTRAVIO/ AVARIA DE BAGAGEM, CARGA, CORRESPOND...       INTERNET
# 53728                                CANCELAMENTO DE VOO       INTERNET
# 53729              SAC - DIFICULDADE DE CONTATO / ACESSO       INTERNET
# 53730     DIFICULDADE DE CONTATO / DEMORA NO ATENDIMENTO       INTERNET
# 53731  DIFICULDADE / ATRASO NA DEVOLUCAO DE VALORES P...       TELEFONE
#
#        PROCUROU EMPRESA RESPONDIDA                 SITUACAO  \
# 0                     S          S      FINALIZADA AVALIADA
# 1                     S          S      FINALIZADA AVALIADA
# 2                     S          S      FINALIZADA AVALIADA
# 3                     S          S               RESPONDIDA
# 4                     S          S      FINALIZADA AVALIADA
# ...                 ...        ...                      ...
# 53727                 S          S  FINALIZADA NAO AVALIADA
# 53728                 S          S  FINALIZADA NAO AVALIADA
# 53729                 S          S      FINALIZADA AVALIADA
# 53730                 S          S      FINALIZADA AVALIADA
# 53731                 S          S      FINALIZADA AVALIADA
#
#       AVALIACAO RECLAMACAO NOTA DO CONSUMIDOR EDICAO DE CONTEUDO  \
# 0                RESOLVIDA                5.0                  N
# 1                RESOLVIDA                5.0                  N
# 2                RESOLVIDA                5.0                  N
# 3                      NAN                NaN                  N
# 4            NAO RESOLVIDA                1.0                  N
# ...                    ...                ...                ...
# 53727         NAO AVALIADA                NaN                  N
# 53728         NAO AVALIADA                NaN                  N
# 53729            RESOLVIDA                5.0                  N
# 53730        NAO RESOLVIDA                1.0                  N
# 53731            RESOLVIDA                5.0                  N
#
#       INTERACAO DO GESTOR CODIGO CLASSIFICADOR ANAC
# 0                       N            S;M;T;D;N;1820
# 1                       N            S;P;O;D;P;2225
# 2                       N            S;P;O;D;P;2210
# 3                       N          S;M;MCO;I;P;4499
# 4                       N            N;N;O;I;N;5300
# ...                   ...                       ...
# 53727                   N          S;M;GRU;D;P;4205
# 53728                   N            S;P;W;I;P;2225
# 53729                   N            S;P;T;D;P;1400
# 53730                   N          S;P;MCO;I;P;2905
# 53731                   N            N;N;O;N;N;0110
#
# [53732 rows x 27 columns]

# %%
df_final.sample(10)
# Out:
#        SIGLA ICAO EMPRESA AEREA  \
# 129533                      ACN
# 323529                      TAM
# 350436                      GLO
# 298186                      GLO
# 342242                      AZU
# 258780                      ACN
# 61211                       ACN
# 291760                      GLO
# 276616                      AZU
# 431052                      TAM
#
#                                             EMPRESA AEREA NUMERO VOO  \
# 129533        AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5357
# 323529                             TAM LINHAS AEREAS S.A.       3910
# 350436  GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       1024
# 298186  GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       1016
# 342242                 AZUL LINHAS AEREAS BRASILEIRAS S/A       2980
# 258780        AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5244
# 61211         AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5114
# 291760  GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       1036
# 276616                 AZUL LINHAS AEREAS BRASILEIRAS S/A       6056
# 431052                             TAM LINHAS AEREAS S.A.       3946
#
#        CODIGO DI CODIGO TIPO LINHA MODELO EQUIPAMENTO  NUMERO DE ASSENTOS  \
# 129533         0                 N               C208                 9.0
# 323529         0                 N               A319               144.0
# 350436         0                 N               B738               186.0
# 298186         0                 N               B737               138.0
# 342242         0                 N               E195               118.0
# 258780         0                 N               C208                 9.0
# 61211          0                 N               C208                 9.0
# 291760         0                 N               B738               186.0
# 276616         0                 N               E195               118.0
# 431052         0                 N               A319               144.0
#
#        SIGLA AEROPORTO ORIGEM  PARTIDA PREVISTA        PARTIDA REAL  ...  \
# 129533                   SBSP  06/08/2024 18:05 2024-08-06 18:09:00  ...
# 323529                   SBSP  31/10/2024 10:00 2024-10-31 09:59:00  ...
# 350436                   SBSP  06/11/2024 13:00 2024-11-06 13:01:00  ...
# 298186                   SBSP  26/10/2024 10:45 2024-10-26 10:45:00  ...
# 342242                   SBSP  24/11/2024 21:20 2024-11-24 21:17:00  ...
# 258780                   SBSP  09/10/2024 08:50 2024-10-09 08:46:00  ...
# 61211                    SBSP  04/07/2024 15:40 2024-07-04 15:40:00  ...
# 291760                   SBSP  15/10/2024 16:45 2024-10-15 16:56:00  ...
# 276616                   SBSP  22/10/2024 13:55 2024-10-22 13:46:00  ...
# 431052                   SBSP  01/12/2024 20:20 2024-12-01 20:12:00  ...
#
#        CIAD DEST                      NOME DEST  MUNICIPIO DEST UF DEST  \
# 129533    RJ0005  JACAREPAGUA - ROBERTO MARINHO  RIO DE JANEIRO      RJ
# 323529    RJ0002                  SANTOS DUMONT  RIO DE JANEIRO      RJ
# 350436    RJ0002                  SANTOS DUMONT  RIO DE JANEIRO      RJ
# 298186    RJ0002                  SANTOS DUMONT  RIO DE JANEIRO      RJ
# 342242    RJ0002                  SANTOS DUMONT  RIO DE JANEIRO      RJ
# 258780    RJ0005  JACAREPAGUA - ROBERTO MARINHO  RIO DE JANEIRO      RJ
# 61211     RJ0005  JACAREPAGUA - ROBERTO MARINHO  RIO DE JANEIRO      RJ
# 291760    RJ0002                  SANTOS DUMONT  RIO DE JANEIRO      RJ
# 276616    RJ0002                  SANTOS DUMONT  RIO DE JANEIRO      RJ
# 431052    RJ0002                  SANTOS DUMONT  RIO DE JANEIRO      RJ
#
#        LATITUDE DEST LONGITUDE DEST DISTANCIA KM HORA PARTIDA REAL  \
# 129533      -22.9875       -43.3700   343.030915          18:09:00
# 323529      -22.9100       -43.1625   365.667493          09:59:00
# 350436      -22.9100       -43.1625   365.667493          13:01:00
# 298186      -22.9100       -43.1625   365.667493          10:45:00
# 342242      -22.9100       -43.1625   365.667493          21:17:00
# 258780      -22.9875       -43.3700   343.030915          08:46:00
# 61211       -22.9875       -43.3700   343.030915          15:40:00
# 291760      -22.9100       -43.1625   365.667493          16:56:00
# 276616      -22.9100       -43.1625   365.667493          13:46:00
# 431052      -22.9100       -43.1625   365.667493          20:12:00
#
#        CLUSTER_HORA           AQO
# 129533         10.0   3087.278232
# 323529          5.0  52656.118920
# 350436          7.0  68014.153605
# 298186          6.0  50462.113965
# 342242         11.0  43148.764115
# 258780          5.0   3087.278232
# 61211           8.0   3087.278232
# 291760          9.0  68014.153605
# 276616          7.0  43148.764115
# 431052         11.0  52656.118920
#
# [10 rows x 36 columns]

# %%
combinacoes_unicas = df_final[['SIGLA ICAO EMPRESA AEREA', 'EMPRESA AEREA']].drop_duplicates()

# 2. (Opcional, mas recomendado) Ordena os valores para facilitar a leitura.
combinacoes_unicas = combinacoes_unicas.sort_values(by='EMPRESA AEREA').reset_index(drop=True)

# 3. Exibe a "lista tabelada" (que é o novo DataFrame).
# Em um notebook .ipynb, basta colocar o nome da variável na última linha da célula.
combinacoes_unicas
# Out:
#   SIGLA ICAO EMPRESA AEREA                                      EMPRESA AEREA
# 0                      ACN        AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
# 1                      AZU                 AZUL LINHAS AEREAS BRASILEIRAS S/A
# 2                      GLO  GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...
# 3                      PTB                  PASSAREDO TRANSPORTES AEREOS S.A.
# 4                      TAM                             TAM LINHAS AEREAS S.A.

# %%
combinacoes_unicas_rec = df_rec[['NOME FANTASIA']].drop_duplicates()

combinacoes_unicas_rec = combinacoes_unicas_rec.sort_values(by='NOME FANTASIA').reset_index(drop=True)

combinacoes_unicas_rec
# Out:
#                            NOME FANTASIA
# 0                  AEROLINEAS ARGENTINAS
# 1                             AEROMEXICO
# 2                             AIR CANADA
# 3                              AIR CHINA
# 4                             AIR EUROPA
# 5                             AIR FRANCE
# 6                               ALITALIA
# 7                  AMASZONAS LINEA AEREA
# 8                      AMERICAN AIRLINES
# 9                            ARAJET S.A.
# 10         AVIANCA - VOOS INTERNACIONAIS
# 11                    AZUL LINHAS AEREAS
# 12           BOLIVIANA DE AVIACION - BOA
# 13                       BRITISH AIRWAYS
# 14                   CABO VERDE AIRLINES
# 15                         COPA AIRLINES
# 16                       DELTA AIR LINES
# 17                         EDELWEISS AIR
# 18                                 EL AL
# 19                              EMIRATES
# 20                    ETHIOPIAN AIRLINES
# 21                              FLYBONDI
# 22                     GOL LINHAS AEREAS
# 23                  IBERIA LINEAS AEREAS
# 24  ITALIA TRASPORTO AEREO (ITA AIRWAYS)
# 25         JETSMART AIRLINES - ARGENTINA
# 26             JETSMART AIRLINES - CHILE
# 27                                   KLM
# 28                  LATAM AIRLINES (TAM)
# 29                             LUFTHANSA
# 30                     MAP LINHAS AEREAS
# 31                         QATAR AIRWAYS
# 32                       ROYAL AIR MAROC
# 33                           SKY AIRLINE
# 34                 SOUTH AFRICAN AIRWAYS
# 35                                 SWISS
# 36        TAAG - LINHAS AEREAS DE ANGOLA
# 37                      TAP AIR PORTUGAL
# 38                      TURKISH AIRLINES
# 39                       UNITED AIRLINES
# 40              VIRGIN ATLANTIC AIRWAYS
# 41                 VOEPASS LINHAS AEREAS

# %%
map_antigo_para_novo = {
    'AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)': 'AZUL CONECTA LTDA',
    'AZUL LINHAS AEREAS BRASILEIRAS S/A': 'AZUL LINHAS AEREAS',
    'GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS S.A.)': 'GOL LINHAS AEREAS',
    'TAM LINHAS AEREAS S.A.': 'LATAM AIRLINES (TAM)',
    'PASSAREDO TRANSPORTES AEREOS S.A.': 'VOEPASS LINHAS AEREAS'
}

map_novo_para_sigla = {
    'AZUL LINHAS AEREAS': 'AZU',
    'GOL LINHAS AEREAS': 'GLO',
    'LATAM AIRLINES (TAM)': 'TAM',
    'VOEPASS LINHAS AEREAS': 'PTB'
}

# %%
df_final['EMPRESA AEREA'] = df_final['EMPRESA AEREA'].replace(map_antigo_para_novo)

# %%
df_rec['SIGLA ICAO EMPRESA AEREA'] = df_rec['NOME FANTASIA'].map(map_novo_para_sigla)

# %%
combinacoes_unicas = df_final[['SIGLA ICAO EMPRESA AEREA', 'EMPRESA AEREA']].drop_duplicates()

combinacoes_unicas = combinacoes_unicas.sort_values(by='EMPRESA AEREA').reset_index(drop=True)

combinacoes_unicas
# Out:
#   SIGLA ICAO EMPRESA AEREA          EMPRESA AEREA
# 0                      ACN      AZUL CONECTA LTDA
# 1                      AZU     AZUL LINHAS AEREAS
# 2                      GLO      GOL LINHAS AEREAS
# 3                      TAM   LATAM AIRLINES (TAM)
# 4                      PTB  VOEPASS LINHAS AEREAS

# %%
df_rec = df_rec.dropna(subset=['SIGLA ICAO EMPRESA AEREA'])

# %%
top_5_empresas = df_final['EMPRESA AEREA'].value_counts().nlargest(5).index
df_top5 = df_final[df_final['EMPRESA AEREA'].isin(top_5_empresas)]
dados_para_grafico = df_top5.groupby(['HORA PARTIDA REAL', 'EMPRESA AEREA']).size().reset_index(name='total_voos')

dados_para_grafico.to_csv('dados/refined/voos_clusterHora_sep_por_empresa.csv', index=False)

# %%
df_final['HORA'] = pd.to_datetime(df_final['HORA PARTIDA REAL'], format='%H:%M:%S').dt.hour

dados_para_grafico = df_final.groupby(['HORA', 'EMPRESA AEREA'])['AQO'].mean().reset_index()

caminho_do_arquivo = 'dados/refined/media_aqo_por_hora_empresa.csv'
dados_para_grafico.to_csv(caminho_do_arquivo, index=False)

# %%
top5_empresas = df_rec['NOME FANTASIA'].value_counts().head(5).index
df_top5 = df_rec[df_rec['NOME FANTASIA'].isin(top5_empresas)].copy()

# PASSO 2: Criar uma coluna de data para o eixo do tempo
df_top5['data_mes'] = pd.to_datetime(
    df_top5['ANO ABERTURA'].astype(str) + '-' + df_top5['MES ABERTURA'].astype(str) + '-01'
)

# PASSO 3: Agrupar por mês e por empresa, e contar as reclamações
reclamacoes_por_mes_empresa = df_top5.groupby(['data_mes', 'NOME FANTASIA']).size().reset_index(name='total_reclamacoes')

# PASSO 4: Exportar o DataFrame final para um arquivo CSV
caminho_arquivo = 'dados/refined/reclamacoes_mensais_top5_comparativo.csv'
reclamacoes_por_mes_empresa.to_csv(caminho_arquivo, index=False)

# %%
df_final.to_csv('dados/refined/voos_sp_rj_2406_2412.csv', index=False)

# %%
df_rec.to_csv('dados/refined/reclamacoes_2406_2412.csv', index=False)
