# %%
import math
import pandas as pd 
import os
import numpy as np

# %%
caminho_dos_arquivos = r'dados/trusted/voos/'

# %%
nomes_dos_arquivos = [
    "dados_voo_202406.csv",
    "dados_voo_202407.csv",
    "dados_voo_202408.csv",
    "dados_voo_202409.csv",
    "dados_voo_202410.csv",
    "dados_voo_202411.csv",
    "dados_voo_202412.csv"
]

# %%
lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]

df_final = pd.concat(lista_de_dfs, ignore_index=True)

df_final.head(5)
print(f"\nNúmero total de linhas no DataFrame final: {len(df_final)}")
# Out:
# C:\Users\ivanm\AppData\Local\Temp\ipykernel_39540\47014420.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]
# C:\Users\ivanm\AppData\Local\Temp\ipykernel_39540\47014420.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]
# Número total de linhas no DataFrame final: 451380
# C:\Users\ivanm\AppData\Local\Temp\ipykernel_39540\47014420.py:1: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   lista_de_dfs = [pd.read_csv(os.path.join(caminho_dos_arquivos, arquivo)) for arquivo in nomes_dos_arquivos]

# %%
df_final
# Out:
#                                             EMPRESA AEREA NUMERO VOO  \
# 0                     CARGOLUX AIRLINES INTERNATIONAL S/A       6225
# 1       GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       1766
# 2       GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       1798
# 3       GOL LINHAS AEREAS S.A. (EX- VRG LINHAS AEREAS ...       9621
# 4                                          LAN CARGO S.A.       1751
# ...                                                   ...        ...
# 451375                      UKRAINE AIR ALLIANCE AIRLINES       5080
# 451376                      UKRAINE AIR ALLIANCE AIRLINES       5004
# 451377                      UKRAINE AIR ALLIANCE AIRLINES       5005
# 451378                      UKRAINE AIR ALLIANCE AIRLINES       5016
# 451379                      UKRAINE AIR ALLIANCE AIRLINES       5017
#
#        CODIGO DI CODIGO TIPO LINHA MODELO EQUIPAMENTO  NUMERO DE ASSENTOS  \
# 0              0                 G               B744                 0.0
# 1              0                 N               B38M               186.0
# 2              0                 N               B38M               186.0
# 3              0                 C               B738                 0.0
# 4              0                 G               B763                 0.0
# ...          ...               ...                ...                 ...
# 451375         9                 I               AN12                 0.0
# 451376         2                 I               AN12                 0.0
# 451377         6                 I               AN12                 0.0
# 451378         2                 I               AN12                 0.0
# 451379         6                 I               AN12                 0.0
#
#        SIGLA ICAO AEROPORTO ORIGEM  PARTIDA PREVISTA      PARTIDA REAL  \
# 0                             SBKP  01/06/2024 06:00  01/06/2024 05:58
# 1                             SBBE  01/06/2024 00:35  01/06/2024 00:24
# 2                             SBRB  01/06/2024 00:50  01/06/2024 03:35
# 3                             SBEG  01/06/2024 02:00  01/06/2024 02:35
# 4                             SBGL  01/06/2024 08:05  01/06/2024 08:11
# ...                            ...               ...               ...
# 451375                        SBEG  13/12/2024 06:00  13/12/2024 09:17
# 451376                        SBSG  15/12/2024 07:00               NAN
# 451377                        SBGL  16/12/2024 09:00  16/12/2024 09:28
# 451378                        SBEG  25/12/2024 08:00               NAN
# 451379                        SBSJ  26/12/2024 03:00  26/12/2024 10:44
#
#        SIGLA ICAO AEROPORTO DESTINO  ... LATITUDE ORIG LONGITUDE ORIG  \
# 0                              SBCT  ...    -23.006944     -47.134444
# 1                              SBSN  ...     -1.384722     -48.478889
# 2                              SBCZ  ...     -9.868333     -67.898056
# 3                              SBGR  ...     -3.041111     -60.050556
# 4                              SBKP  ...    -22.810000     -43.250556
# ...                             ...  ...           ...            ...
# 451375                         SBSJ  ...     -3.041111     -60.050556
# 451376                         SBGL  ...     -5.768889     -35.366389
# 451377                         SBEG  ...    -22.810000     -43.250556
# 451378                         SBSJ  ...     -3.041111     -60.050556
# 451379                         SBEG  ...    -23.228889     -45.871111
#
#        CODIGO OACI_y CIAD DEST                                     NOME DEST  \
# 0               SBCT    PR0001                                   AFONSO PENA
# 1               SBSN    PA0002                        MAESTRO WILSON FONSECA
# 2               SBCZ    AC0002                               CRUZEIRO DO SUL
# 3               SBGR    SP0002   GUARULHOS - GOVERNADOR ANDRE FRANCO MONTORO
# 4               SBKP    SP0003                                     VIRACOPOS
# ...              ...       ...                                           ...
# 451375          SBSJ    SP0008               PROFESSOR URBANO ERNESTO STUMPF
# 451376          SBGL    RJ0001  RIO DE JANEIRO/GALEAO – ANTONIO CARLOS JOBIM
# 451377          SBEG    AM0001                                 EDUARDO GOMES
# 451378          SBSJ    SP0008               PROFESSOR URBANO ERNESTO STUMPF
# 451379          SBEG    AM0001                                 EDUARDO GOMES
#
#        MUNICIPIO ATENDIDO DEST UF DEST LATITUDE DEST LONGITUDE DEST  \
# 0                     CURITIBA      PR    -25.531667     -49.176111
# 1                     SANTAREM      PA     -2.424722     -54.785833
# 2              CRUZEIRO DO SUL      AC     -7.599444     -72.769444
# 3                    GUARULHOS      SP    -23.435556     -46.473056
# 4                     CAMPINAS      SP    -23.006944     -47.134444
# ...                        ...     ...           ...            ...
# 451375     SAO JOSE DOS CAMPOS      SP    -23.228889     -45.871111
# 451376          RIO DE JANEIRO      RJ    -22.810000     -43.250556
# 451377                  MANAUS      AM     -3.041111     -60.050556
# 451378     SAO JOSE DOS CAMPOS      SP    -23.228889     -45.871111
# 451379                  MANAUS      AM     -3.041111     -60.050556
#
#        DISTANCIA KM
# 0        348.759491
# 1        710.378651
# 2        591.819954
# 3       2697.275751
# 4        398.396819
# ...             ...
# 451375  2714.305622
# 451376  2075.064170
# 451377  2847.404725
# 451378  2714.305622
# 451379  2714.305622
#
# [451380 rows x 32 columns]

# %%
df_final.isnull().sum().sort_values(ascending=False)
# Out:
# DISTANCIA KM                    3155
# MUNICIPIO ATENDIDO DEST         1582
# NOME DEST                       1582
# CODIGO OACI_y                   1582
# LATITUDE DEST                   1582
# UF DEST                         1582
# LONGITUDE DEST                  1582
# CIAD DEST                       1582
# LATITUDE ORIG                   1573
# CODIGO OACI_x                   1573
# NOME ORIG                       1573
# CIAD ORIG                       1573
# LONGITUDE ORIG                  1573
# UF ORIG                         1573
# MUNICIPIO ATENDIDO ORIG         1573
# EMPRESA AEREA                      0
# SITUACAO PARTIDA                   0
# REFERENCIA                         0
# JUSTIFICATIVA                      0
# SITUACAO VOO                       0
# CHEGADA REAL                       0
# CHEGADA PREVISTA                   0
# SIGLA ICAO AEROPORTO DESTINO       0
# PARTIDA REAL                       0
# PARTIDA PREVISTA                   0
# SIGLA ICAO AEROPORTO ORIGEM        0
# NUMERO DE ASSENTOS                 0
# MODELO EQUIPAMENTO                 0
# CODIGO TIPO LINHA                  0
# CODIGO DI                          0
# NUMERO VOO                         0
# SITUACAO CHEGADA                   0
# dtype: int64

# %%
print(len(df_final))
# Out:
# 451380

# %%
novos_nomes = {
    'SIGLA ICAO AEROPORTO DESTINO' : 'SIGLA AEROPORTO DESTINO',
    'MUNICIPIO ATENDIDO ORIG' : 'MUNICIPIO ORIG',
    'MUNICIPIO ATENDIDO DEST' : 'MUNICIPIO DEST',
    'SIGLA ICAO AEROPORTO ORIGEM' : 'SIGLA AEROPORTO ORIGEM',
}

df_final.rename(columns=novos_nomes, inplace=True)

# %%
df_final = df_final[
    (df_final['UF ORIG'] == 'SP') & 
    (df_final['MUNICIPIO ORIG'] == 'SAO PAULO') & 
    (df_final['MUNICIPIO DEST'] == 'RIO DE JANEIRO') & 
    (df_final['UF DEST'] == 'RJ')
].copy()

print(f"\nNúmero total de voos de São Paulo para Rio de Janeiro: {len(df_final)}")
# Out:
# Número total de voos de São Paulo para Rio de Janeiro: 12693

# %%
df_final['PARTIDA REAL'] = pd.to_datetime(df_final['PARTIDA REAL'], format='%d/%m/%Y %H:%M', errors='coerce')

df_final['HORA PARTIDA REAL'] = df_final['PARTIDA REAL'].dt.time

# %%
def mapear_cluster_hora(hora_integer):
    if 0 <= hora_integer < 2:
        return 1
    elif 2 <= hora_integer < 4:
        return 2
    elif 4 <= hora_integer < 6:
        return 3
    elif 6 <= hora_integer < 8:
        return 4
    elif 8 <= hora_integer < 10:
        return 5
    elif 10 <= hora_integer < 12:
        return 6
    elif 12 <= hora_integer < 14:
        return 7
    elif 14 <= hora_integer < 16:
        return 8
    elif 16 <= hora_integer < 18:
        return 9
    elif 18 <= hora_integer < 20:
        return 10
    elif 20 <= hora_integer < 22:
        return 11
    elif 22 <= hora_integer <= 23:
        return 12
    else:
        return np.nan


df_final['CLUSTER_HORA'] = df_final['PARTIDA REAL'].dt.hour.apply(mapear_cluster_hora)

# %%
df_final['AQO'] = df_final['NUMERO DE ASSENTOS'] * df_final['DISTANCIA KM']

# %%
df_final
# Out:
#                                       EMPRESA AEREA NUMERO VOO CODIGO DI  \
# 11      AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5121         0
# 13      AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5232         0
# 16      AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5114         0
# 24      AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5220         0
# 25      AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)       5226         0
# ...                                             ...        ...       ...
# 451061                       TAM LINHAS AEREAS S.A.       3930         0
# 451063                       TAM LINHAS AEREAS S.A.       3932         0
# 451066                       TAM LINHAS AEREAS S.A.       3938         0
# 451067                       TAM LINHAS AEREAS S.A.       3940         0
# 451068                       TAM LINHAS AEREAS S.A.       3944         0
#
#        CODIGO TIPO LINHA MODELO EQUIPAMENTO  NUMERO DE ASSENTOS  \
# 11                     N               C208                 9.0
# 13                     N               C208                 9.0
# 16                     N               C208                 9.0
# 24                     N               C208                 9.0
# 25                     N               C208                 9.0
# ...                  ...                ...                 ...
# 451061                 N               A319               144.0
# 451063                 N               A319               144.0
# 451066                 N               A319               144.0
# 451067                 N               A319               144.0
# 451068                 N               A319               144.0
#
#        SIGLA AEROPORTO ORIGEM  PARTIDA PREVISTA        PARTIDA REAL  \
# 11                       SBSP  01/06/2024 06:25 2024-06-01 06:20:00
# 13                       SBSP  01/06/2024 10:45 2024-06-01 10:40:00
# 16                       SBSP  02/06/2024 15:40 2024-06-02 15:38:00
# 24                       SBSP  02/06/2024 13:40 2024-06-02 13:33:00
# 25                       SBSP  02/06/2024 20:10 2024-06-02 20:17:00
# ...                       ...               ...                 ...
# 451061                   SBSP  31/12/2024 12:00 2024-12-31 12:04:00
# 451063                   SBSP  31/12/2024 19:40 2024-12-31 19:35:00
# 451066                   SBSP  31/12/2024 20:35 2024-12-31 20:22:00
# 451067                   SBSP  31/12/2024 20:55 2024-12-31 20:47:00
# 451068                   SBSP  31/12/2024 20:00 2024-12-31 19:49:00
#
#        SIGLA AEROPORTO DESTINO  ... CIAD DEST                      NOME DEST  \
# 11                        SBJR  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 13                        SBJR  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 16                        SBJR  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 24                        SBJR  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# 25                        SBJR  ...    RJ0005  JACAREPAGUA - ROBERTO MARINHO
# ...                        ...  ...       ...                            ...
# 451061                    SBRJ  ...    RJ0002                  SANTOS DUMONT
# 451063                    SBRJ  ...    RJ0002                  SANTOS DUMONT
# 451066                    SBRJ  ...    RJ0002                  SANTOS DUMONT
# 451067                    SBRJ  ...    RJ0002                  SANTOS DUMONT
# 451068                    SBRJ  ...    RJ0002                  SANTOS DUMONT
#
#         MUNICIPIO DEST UF DEST LATITUDE DEST LONGITUDE DEST DISTANCIA KM  \
# 11      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 13      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 16      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 24      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# 25      RIO DE JANEIRO      RJ      -22.9875       -43.3700   343.030915
# ...                ...     ...           ...            ...          ...
# 451061  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451063  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451066  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451067  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
# 451068  RIO DE JANEIRO      RJ      -22.9100       -43.1625   365.667493
#
#        HORA PARTIDA REAL CLUSTER_HORA           AQO
# 11              06:20:00          4.0   3087.278232
# 13              10:40:00          6.0   3087.278232
# 16              15:38:00          8.0   3087.278232
# 24              13:33:00          7.0   3087.278232
# 25              20:17:00         11.0   3087.278232
# ...                  ...          ...           ...
# 451061          12:04:00          7.0  52656.118920
# 451063          19:35:00         10.0  52656.118920
# 451066          20:22:00         11.0  52656.118920
# 451067          20:47:00         11.0  52656.118920
# 451068          19:49:00         10.0  52656.118920
#
# [12693 rows x 35 columns]

# %%
df_final.to_csv('dados/refined/voos_sp_rj_2406_2412.csv', index=False)
